# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as exp

# %%
df=pd.read_csv('ai_student.csv')

# %%
df.shape
# Out:
# (50000, 16)

# %%
df.head()
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# ...

# %%
df.sample(10)
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 28419      128420       Business        Senior             2.649
# 41408      141409     Humanities     Sophomore             3.438
# 29250      129251     Humanities        Senior             3.826
# 42052      142053           Arts        Junior             3.013
# 31101      131102           Arts      Freshman             2.133
# 14438      114439       Business      Freshman             2.407
# 35763      135764       Business        Senior             2.988
# 25662      125663           Arts     Sophomore             3.838
# 7399       107400           STEM     Sophomore             3.495
# 2532       102533           STEM      Freshman             2.497
#
#        Weekly_GenAI_Hours          Primary_Use_Case Prompt_Engineering_Skill  \
# 28419                4.40                  Ideation                 Beginner
# 41408               16.03      Copywriting/Drafting             Intermediate
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  50000 non-null  int64
#  1   Major_Category              50000 non-null  str
#  2   Year_of_Study               50000 non-null  str
#  3   Pre_Semester_GPA            50000 non-null  float64
#  4   Weekly_GenAI_Hours          50000 non-null  float64
#  5   Primary_Use_Case            50000 non-null  str
#  6   Prompt_Engineering_Skill    50000 non-null  str
#  7   Tool_Diversity              50000 non-null  int64
#  8   Paid_Subscription           50000 non-null  bool
#  9   Traditional_Study_Hours     50000 non-null  float64
#  10  Perceived_AI_Dependency     50000 non-null  int64
#  11  Institutional_Policy        50000 non-null  str
#  12  Anxiety_Level_During_Exams  50000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                    0
# Major_Category                0
# Year_of_Study                 0
# Pre_Semester_GPA              0
# Weekly_GenAI_Hours            0
# Primary_Use_Case              0
# Prompt_Engineering_Skill      0
# Tool_Diversity                0
# Paid_Subscription             0
# Traditional_Study_Hours       0
# Perceived_AI_Dependency       0
# Institutional_Policy          0
# Anxiety_Level_During_Exams    0
# Post_Semester_GPA             0
# Skill_Retention_Score         0
# Burnout_Risk_Level            0
# dtype: int64

# %%
df.describe()
# Out:
#           Student_ID  Pre_Semester_GPA  Weekly_GenAI_Hours  Tool_Diversity  \
# count   50000.000000      50000.000000        50000.000000     50000.00000
# mean   125000.500000          3.146102            8.427752         2.80026
# std     14433.901067          0.478854            8.269490         1.18802
# min    100001.000000          1.183000            0.000000         1.00000
# 25%    112500.750000          2.834000            2.390000         2.00000
# 50%    125000.500000          3.210000            5.800000         3.00000
# 75%    137500.250000          3.521000           11.720000         4.00000
# max    150000.000000          3.998000           40.000000         5.00000
#
#        Traditional_Study_Hours  Perceived_AI_Dependency  \
# count             50000.000000             50000.000000
# mean                 11.209271                 3.505360
# std                   5.156426                 1.820812
# min                   1.000000                 1.000000
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    50000
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                             Student_ID  Pre_Semester_GPA  Weekly_GenAI_Hours  \
# Student_ID                    1.000000          0.002275            0.001577
# Pre_Semester_GPA              0.002275          1.000000           -0.001084
# Weekly_GenAI_Hours            0.001577         -0.001084            1.000000
# Tool_Diversity               -0.001187         -0.005671            0.008411
# Paid_Subscription            -0.000319         -0.001027            0.196943
# Traditional_Study_Hours       0.000648         -0.004620           -0.157368
# Perceived_AI_Dependency       0.002768          0.000701            0.665479
# Anxiety_Level_During_Exams    0.009670         -0.000667            0.269080
# Post_Semester_GPA            -0.000602          0.926781           -0.018600
# Skill_Retention_Score        -0.001737          0.099019           -0.118099
#
#                             Tool_Diversity  Paid_Subscription  \
# ...

# %%
for col in df.select_dtypes(include=['object']).columns:
    print(f'{col}:{df[col].unique()}')
# Out:
# Major_Category:<StringArray>
# ['Humanities', 'Medical', 'Business', 'STEM', 'Arts']
# Length: 5, dtype: str
# Year_of_Study:<StringArray>
# ['Senior', 'Junior', 'Freshman', 'Sophomore', 'Graduate']
# Length: 5, dtype: str
# Primary_Use_Case:<StringArray>
# [     'Copywriting/Drafting',                  'Ideation',
#        'Summarizing_Reading', 'Debugging/Troubleshooting',
#   'Direct_Answer_Generation']
# Length: 5, dtype: str
# Prompt_Engineering_Skill:<StringArray>
# ['Beginner', 'Advanced', 'Intermediate']
# Length: 3, dtype: str
# Institutional_Policy:<StringArray>
# ['Allowed_With_Citation', 'Strict_Ban', 'Actively_Encouraged']
# Length: 3, dtype: str
# Burnout_Risk_Level:<StringArray>
# ['High', 'Low', 'Medium']
# Length: 3, dtype: str
# ...

# %%
df.select_dtypes(include=['object']).nunique()
# Out:
# C:\Users\Ahmad Qamar\AppData\Local\Temp\ipykernel_2936\2518819223.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include=['object']).nunique()
# Major_Category              5
# Year_of_Study               5
# Primary_Use_Case            5
# Prompt_Engineering_Skill    3
# Institutional_Policy        3
# Burnout_Risk_Level          3
# dtype: int64

# %%
df.nunique()
# Out:
# Student_ID                    50000
# Major_Category                    5
# Year_of_Study                     5
# Pre_Semester_GPA               2389
# Weekly_GenAI_Hours             3566
# Primary_Use_Case                  5
# Prompt_Engineering_Skill          3
# Tool_Diversity                    5
# Paid_Subscription                 2
# Traditional_Study_Hours        2516
# Perceived_AI_Dependency          10
# Institutional_Policy              3
# Anxiety_Level_During_Exams       10
# Post_Semester_GPA              2269
# Skill_Retention_Score          5872
# Burnout_Risk_Level                3
# dtype: int64

# %%
df.drop('Student_ID', axis=1, inplace=True)

# %%
df.sample()
# Out:
#       Major_Category Year_of_Study  Pre_Semester_GPA  Weekly_GenAI_Hours  \
# 49631           STEM      Freshman             2.853               10.16
#
#                Primary_Use_Case Prompt_Engineering_Skill  Tool_Diversity  \
# 49631  Direct_Answer_Generation                 Beginner               1
#
#        Paid_Subscription  Traditional_Study_Hours  Perceived_AI_Dependency  \
# 49631              False                     11.8                        4
#
#         Institutional_Policy  Anxiety_Level_During_Exams  Post_Semester_GPA  \
# 49631  Allowed_With_Citation                           6              3.048
#
#        Skill_Retention_Score Burnout_Risk_Level
# 49631                  57.61                Low

# %% [markdown]
# # Univariate Analysis
# ### Visiualization For Categorical Data

# %%
sns.countplot(x=df['Major_Category'])
# Out:
# <Axes: xlabel='Major_Category', ylabel='count'>

# %%
sns.countplot(x=df['Year_of_Study'])
# Out:
# <Axes: xlabel='Year_of_Study', ylabel='count'>

# %%
df['Primary_Use_Case'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
sns.countplot(x=df['Prompt_Engineering_Skill'])
# Out:
# <Axes: xlabel='Prompt_Engineering_Skill', ylabel='count'>

# %%
df['Paid_Subscription'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
sns.countplot(x=df['Burnout_Risk_Level'])
# Out:
# <Axes: xlabel='Burnout_Risk_Level', ylabel='count'>

# %%
df['Institutional_Policy'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %% [markdown]
# # Visiualization For Numarical Data

# %%
df.sample()
# Out:
#       Major_Category Year_of_Study  Pre_Semester_GPA  Weekly_GenAI_Hours  \
# 24904        Medical     Sophomore             3.535                 1.4
#
#                Primary_Use_Case Prompt_Engineering_Skill  Tool_Diversity  \
# 24904  Direct_Answer_Generation             Intermediate               1
#
#        Paid_Subscription  Traditional_Study_Hours  Perceived_AI_Dependency  \
# 24904               True                    22.86                        4
#
#         Institutional_Policy  Anxiety_Level_During_Exams  Post_Semester_GPA  \
# 24904  Allowed_With_Citation                           8              3.717
#
#        Skill_Retention_Score Burnout_Risk_Level
# 24904                  73.84                Low

# %%
df['Pre_Semester_GPA'].skew()
# Out:
# np.float64(-0.602042795770214)

# %%
sns.distplot(df['Pre_Semester_GPA'])
# Out:
# C:\Users\Ahmad Qamar\AppData\Local\Temp\ipykernel_2936\1498510753.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Pre_Semester_GPA'])
# <Axes: xlabel='Pre_Semester_GPA', ylabel='Density'>

# %%
df['Post_Semester_GPA'].skew()
# Out:
# np.float64(-0.6750590054046929)

# %%
sns.distplot(df['Post_Semester_GPA'])
# Out:
# C:\Users\Ahmad Qamar\AppData\Local\Temp\ipykernel_2936\2217500408.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Post_Semester_GPA'])
# <Axes: xlabel='Post_Semester_GPA', ylabel='Density'>

# %%
sns.boxplot(x=df['Post_Semester_GPA'])
# Out:
# <Axes: xlabel='Post_Semester_GPA'>

# %%
sns.histplot(x=df['Weekly_GenAI_Hours'],bins=5)
# Out:
# <Axes: xlabel='Weekly_GenAI_Hours', ylabel='Count'>

# %%
sns.histplot(x=df['Tool_Diversity'],bins=5)
# Out:
# <Axes: xlabel='Tool_Diversity', ylabel='Count'>

# %%
df['Tool_Diversity'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
sns.histplot(df['Traditional_Study_Hours'],bins=5)
# Out:
# <Axes: xlabel='Traditional_Study_Hours', ylabel='Count'>

# %%
sns.histplot(x=df['Perceived_AI_Dependency'],bins=5)
# Out:
# <Axes: xlabel='Perceived_AI_Dependency', ylabel='Count'>

# %%
sns.histplot(x=df['Anxiety_Level_During_Exams'],bins=5)
# Out:
# <Axes: xlabel='Anxiety_Level_During_Exams', ylabel='Count'>

# %%
sns.histplot(x=df['Skill_Retention_Score'],bins=5)
# Out:
# <Axes: xlabel='Skill_Retention_Score', ylabel='Count'>

# %% [markdown]
# # Bivariate Analysis
# ## Numerical – Numerical

# %%
df['Post_Semester_GPA'].corr(df['Traditional_Study_Hours'])
# Out:
# np.float64(0.1376533204171766)

# %%
sns.scatterplot(x=df['Post_Semester_GPA'],y=df['Traditional_Study_Hours'])
# Out:
# <Axes: xlabel='Post_Semester_GPA', ylabel='Traditional_Study_Hours'>

# %% [markdown]
# # Multivariate Analysis

# %%
sns.clustermap(df.pivot_table(values='Skill_Retention_Score', index='Year_of_Study', 
columns='Major_Category'))

# %%
df.select_dtypes(include='object').nunique()
# Out:
# C:\Users\Ahmad Qamar\AppData\Local\Temp\ipykernel_2936\3404847108.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include='object').nunique()
# Major_Category              5
# Year_of_Study               5
# Primary_Use_Case            5
# Prompt_Engineering_Skill    3
# Institutional_Policy        3
# Burnout_Risk_Level          3
# dtype: int64

# %%
df.select_dtypes(include='number').nunique()
# Out:
# Pre_Semester_GPA              2389
# Weekly_GenAI_Hours            3566
# Tool_Diversity                   5
# Traditional_Study_Hours       2516
# Perceived_AI_Dependency         10
# Anxiety_Level_During_Exams      10
# Post_Semester_GPA             2269
# Skill_Retention_Score         5872
# dtype: int64
